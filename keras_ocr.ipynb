# %%
# !pip install -q keras-ocr

# %%
import keras_ocr
import cv2
import matplotlib.pyplot as plt

# %%
pipeline = keras_ocr.pipeline.Pipeline()
# Out:
# Looking for C:\Users\certainty\.keras-ocr\craft_mlt_25k.h5
# Looking for C:\Users\certainty\.keras-ocr\crnn_kurapan.h5

# %%
images = [
    keras_ocr.tools.read(img) for img in ['chat_masala.jpg',
                                          'lays2.jpg'
    ]
]

# %%
len(images)
# Out:
# 2

# %%
plt.figure(figsize = (10,20))
plt.imshow(images[0])

# %%
plt.figure(figsize = (10,20))
plt.imshow(images[1])

# %%
prediction_groups = pipeline.recognize(images)
# Out:
# ...
# 1/1 [==============================] - 4s 4s/step

# %%
type(prediction_groups[1][0])
# Out:
# tuple

# %%
len(prediction_groups[1])
# Out:
# 3

# %%
text= prediction_groups[1]

# %%
txt = []
for i in text:
    text.append(prediction_groups[1][0][0])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [28], in <cell line: 2>()
#       1 txt = []
# ----> 2 for i in text:
#       3     text.append(prediction_groups[1][0][0])
#
# KeyboardInterrupt:

# %%
txt = []
predicted_image_1 = prediction_groups[0]
for text, box in predicted_image_1:
    txt.append(text)

# %%
txt
# Out:
# ['pack',
#  'export',
#  'balad',
#  'balaji',
#  'wafers',
#  'chas',
#  'chaska',
#  'tickling',
#  'splcy',
#  'potato',
#  'chips',
#  'not',
#  'w',
#  'd',
#  'po',
#  'not',
#  '40',
#  'calal',
#  'g',
#  'oz',
#  'ready',
#  'to',
#  'eat']

# %%
if 'balaji' in txt:
    print("it is balaji chips packet")
else:
    print("it is lays wafer")
# Out:
# it is balaji chips packet

# %%
len(text)
# Out:
# 3

# %%
fig, axs = plt.subplots(nrows=len(images), figsize=(10, 20))
for ax, image, predictions in zip(axs, images, prediction_groups):
    keras_ocr.tools.drawAnnotations(image=image, 
                                    predictions=predictions, 
                                    ax=ax)

# %% [markdown]
# ### for single image

# %%
image1 = keras_ocr.tools.read('new_wafer.jpg')

# %%
image1 = [
    keras_ocr.tools.read(img) for img in ['b_l.jpeg'
                            
    ]
]

# %%
len(image1)
# Out:
# 236

# %%
plt.figure(figsize = (10,20))
plt.imshow(image1[0])

# %%
prediction = pipeline.recognize(image1)
# Out:
# ...
# 1/1 [==============================] - 1s 611ms/step

# %%
t = []
for text in prediction:
    t.append(text)

# %%
t
# Out:
# [[('com',
#    array([[ 95.,   9.],
#           [112.,   9.],
#           [112.,  15.],
#           [ 95.,  15.]], dtype=float32)),
#   ('lays',
#    array([[ 64.,  26.],
#           [103.,  26.],
#           [103.,  47.],
#           [ 64.,  47.]], dtype=float32)),
#   ('balaji',
#    array([[221.,  39.],
#           [283.,  39.],
#           [283.,  53.],
#           [221.,  53.]], dtype=float32)),
#   ('waers',
#    array([[235.,  54.],
#           [267.,  54.],
#           [267.,  62.],
#           [235.,  62.]], dtype=float32)),
#   ('maxx',
#    array([[ 44.,  58.],
#           [123.,  58.],
#           [123.,  86.],
#           [ 44.,  86.]], dtype=float32)),
#   ('rombley',
#    array([[183.57997 ,  87.06001 ],
#           [308.31995 ,  69.240005],
#           [314.59998 , 113.2     ],
#           [189.85999 , 131.02    ]], dtype=float32)),
#   ('hotn',
#    array([[43., 84.],
#           [70., 84.],
#           [70., 94.],
#           [43., 94.]], dtype=float32)),
# ...

# %%
import matplotlib.pyplot as plt
import keras_ocr
pipeline = keras_ocr.pipeline.Pipeline()

img = keras_ocr.tools.read('untitled.png')

prediction_groups = pipeline.recognize([img])

keras_ocr.tools.drawAnnotations(image=img, predictions=prediction_groups[0])
# Out:
# Looking for C:\Users\certainty\.keras-ocr\craft_mlt_25k.h5
# Looking for C:\Users\certainty\.keras-ocr\crnn_kurapan.h5
# ...
# 1/1 [==============================] - 3s 3s/step
# <AxesSubplot:>

# %%
predicted_image_1 = prediction_groups[0]

# %%
txt = []
for text, box in predicted_image_1:
    txt.append(text)

# %%
txt
# Out:
# ['balaji',
#  'balaji',
#  'balaji',
#  'nafers',
#  'wafers',
#  'poprings',
#  'simply',
#  'derl',
#  'salted',
#  'perl',
#  'masala',
#  'see',
#  'cesgo',
#  'san',
#  'atov']

# %%
if 'balaji' in txt:
    print("it is balaji chips packet")
else:
    print("it is lays wafer")
# Out:
# it is balaji chips packet

# %%
img2=cv2.imread('b_l.jpeg')
img3 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
[[221.  39.]
 [283.  39.]
 [283.  53.]
 [221.  53.]]

# %%
text = ["3 peck balad eco balaji namkeen poplings masala d", 
"1ol balad pr balaji wafers masti tomato o gnl cruntchy tet an tie fres"]

# %%
txt_data = [] 
for i in text:
    i[].split(",")
    txt_data.append(i)

# %%
txt_data
# Out:
# '3 peck balad eco balaji namkeen poplings masala d'

# %%
target = ["balaji_masala", "balaji_cruntchy"]

# %%
comp_list1 = dict([((txt_data[i]), target[i])
                      for i in range(len(txt_data))])

# %%
comp_list1
# Out:
# {'3 peck balad eco balaji namkeen poplings masala d': 'balaji_masala',
#  '1ol balad pr balaji wafers masti tomato o gnl cruntchy tet an tie fres': 'balaji_cruntchy'}

# %%
for i in text:
    if 'balaji' in i:
        if 'namkeen' in i:
            print("balaji_masala Packet")
    if 'balaji' in i:
        if 'tomato' in i:
            print("balaji_cruntchy Packet")
    else: 
        print("other than both")
# Out:
# balaji_masala Packet
# balaji_cruntchy Packet
