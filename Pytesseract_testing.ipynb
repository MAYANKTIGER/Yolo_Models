# %%
from PIL import Image
import pytesseract
import argparse
import cv2
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import csv
import nltk
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import wordnet

# %%
# !pip install pytesseract

# %%
# !pip install tesseract-ocr

# %%
image=cv2.imread('lays2.jpg',0)

# %%
import pytesseract

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Users\certainty\AppData\Local\Tesseract-OCR\tesseract.exe'

# %%
#convert it into text
text=(pytesseract.image_to_string(image)).lower()
print(text)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Input In [16], in <cell line: 2>()
#       1 #convert it into text
# ----> 2 text=(pytesseract.image_to_string(image)).lower()
#       3 print(text)
#
# File ~\anaconda3\lib\site-packages\pytesseract\pytesseract.py:416, in image_to_string(image, lang, config, nice, output_type, timeout)
#     411 """
#     412 Returns the result of a Tesseract OCR run on the provided image to string
#     413 """
#     414 args = [image, 'txt', lang, config, nice, timeout]
# --> 416 return {
#     417     Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     418     Output.DICT: lambda: {'text': run_and_get_output(*args)},
#     419     Output.STRING: lambda: run_and_get_output(*args),
#     420 }[output_type]()
#
# File ~\anaconda3\lib\site-packages\pytesseract\pytesseract.py:419, in image_to_string.<locals>.<lambda>()
#     411 """
# ...

# %%
import cv2 
import pytesseract

# %%
img = cv2.imread('balaji1.jpg')

# %%
im = plt.imshow(img)

# %%
custom_config = r'--oem 3 --psm 4'

# %%
txt = pytesseract.image_to_string(img, config=custom_config)

# %%
# txt = txt.strip('\n')
import re

# %%
k = []
for i in txt:
    j = i.strip('\n').
    k.append(j)
print(k)
# Out:
# ['a', 'e', ' ', 'f', 't', ',', '', '', '2', '', 'w', 'e', '', '3', ' ', 'S', '', 'x', 'f', ' ', '>', '', '2', ' ', '2', '', 'w', 'e', ' ', '"', '', 'w', 's', '', 'c', 'S', ')', '', '&', '', 'r', 'a', 's', ' ', 'a', ' ', 'a', 'i', 's', ' ', 'o', 'f', '', 'q', ' ', 'i', '', '5', ' ', 'F', 'F', ' ', 'o', 'n', '', '[', 'B', 'A', 'L', 'A', 'J', 'I', ' ', 'e', 's', '', 'W', 'A', 'F', 'E', 'R', 'S', ' ', '2', '', 'f', ',', ' ', '¥', ' ', '‘', ' ', '“', '5', '', '', 'J', '', '', '5', ' ', '‘', '', 's', 'h', 'u', 't', 't', 'e', 'r', 's', 't', 's', 'c', 'k', ':', ' ', 'r', 'i', 'e', 's', '']

# %%
new_string = re.sub(r'\n', '', txt)

# %%
new_string
# Out:
# 'ae ft,2we3 Sxf >2 2we "wscS)&ras a ais ofq i5 FF on[BALAJI esWAFERS 2f, ¥ ‘ “5J5 ‘shutterstsck: ries'

# %%
text=(pytesseract.image_to_string(img, config=custom_config)).lower()
print(text)
# Out:
# - of 5
# si gis
# ~~ a
# | = ro
# a alaii)
# i \ af
# : ee aq tal ley : :
# 4 = ream a
# lay a = gy , f hf :
# % ‘ rm & . s < 4
# — & ~ }
# 7 a ee?
# shutte ~ ae a ’
# rst« s. ag
# ack’ ° =
# ; i 4

# %%
text=(pytesseract.image_to_string)
print(text)
# Out:
# <function image_to_string at 0x00000154BD143DC0>

# %%
from PIL import Image
import pytesseract

# %%
img = Image.open('balaji1.jpg')

# %%
text = pytesseract.image_to_string(img, config=custom_config)

# %%
text
# Out:
# 'QF\nef a\n3 re BN ew\nRS\na)\n2 &\nqe aie ; |\n; : ; S&S . %\nBALA a\nASTI ?\n5 ¥ \\NAF es\nWAEERS 2)\n; a \\ y \\ 4 5\nRees. iS Le\nEe j 7\n, Y ‘\n7, ,) , ; 2\nes =. yas f ox ¥ |\nsg me — wf\noe as\nos eae aes ‘\nshutterstsck: : ee : ¢ =\n'

# %%
target = pytesseract.image_to_string(img, lang='eng', config=custom_config)

# %%
target
# Out:
# 'QF\nef a\n3 re BN ew\nRS\na)\n2 &\nqe aie ; |\n; : ; S&S . %\nBALA a\nASTI ?\n5 ¥ \\NAF es\nWAEERS 2)\n; a \\ y \\ 4 5\nRees. iS Le\nEe j 7\n, Y ‘\n7, ,) , ; 2\nes =. yas f ox ¥ |\nsg me — wf\noe as\nos eae aes ‘\nshutterstsck: : ee : ¢ =\n'

# %%
# target = pytesseract.image_to_string(img ,config='--psm 2')

# %%
# Out:
#   Input In [168]
#     config='outputbase("digits'")
#                                  ^
# SyntaxError: EOL while scanning string literal
